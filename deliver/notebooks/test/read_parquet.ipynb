# %%
# 読み込みファイルパスの設定とimportしたいmoduleパス(pythonパス)の設定
from pathlib import Path
import os, sys

CURRENT_DIR = Path(os.getcwd())
PJ_DIR = CURRENT_DIR.parent.parent
DATA_DIR = PJ_DIR / "data"

import polars as pl

# %%
fp = DATA_DIR / "kessan.parquet"
df = pl.read_parquet(fp)

df.filter(pl.col("mcode")==9997).filter(pl.col("settlement_type")=="予")
# Out:
# shape: (10, 11)
# ┌───────┬─────────────┬─────────────┬────────────┬───┬────────────┬────────────┬──────────┬────────┐
# │ mcode ┆ settlement_ ┆ settlement_ ┆ announceme ┆ … ┆ final_prof ┆ reviced_ep ┆ dividend ┆ quater │
# │ ---   ┆ date        ┆ type        ┆ nt_date    ┆   ┆ it         ┆ s          ┆ ---      ┆ ---    │
# │ i64   ┆ ---         ┆ ---         ┆ ---        ┆   ┆ ---        ┆ ---        ┆ f64      ┆ i64    │
# │       ┆ date        ┆ str         ┆ date       ┆   ┆ i64        ┆ f64        ┆          ┆        │
# ╞═══════╪═════════════╪═════════════╪════════════╪═══╪════════════╪════════════╪══════════╪════════╡
# │ 9997  ┆ 2021-03-31  ┆ 予          ┆ 2020-05-13 ┆ … ┆ 5200       ┆ 53.8       ┆ 16.0     ┆ 4      │
# │ 9997  ┆ 2021-03-31  ┆ 予          ┆ 2020-10-29 ┆ … ┆ 9500       ┆ 98.3       ┆ 16.0     ┆ 4      │
# │ 9997  ┆ 2021-03-31  ┆ 予          ┆ 2021-01-28 ┆ … ┆ 10500      ┆ 108.6      ┆ 16.5     ┆ 4      │
# │ 9997  ┆ 2022-03-31  ┆ 予          ┆ 2021-05-13 ┆ … ┆ 12500      ┆ 129.3      ┆ 19.0     ┆ 4      │
# │ 9997  ┆ 2022-03-31  ┆ 予          ┆ 2022-01-31 ┆ … ┆ 9800       ┆ 101.4      ┆ 19.0     ┆ 4      │
# │ 9997  ┆ 2023-03-31  ┆ 予          ┆ 2022-05-13 ┆ … ┆ 10600      ┆ 109.6      ┆ 20.0     ┆ 4      │
# │ 9997  ┆ 2023-03-31  ┆ 予          ┆ 2022-10-28 ┆ … ┆ 10000      ┆ 103.4      ┆ 20.0     ┆ 4      │
# │ 9997  ┆ 2024-03-31  ┆ 予          ┆ 2023-05-12 ┆ … ┆ 9400       ┆ 97.2       ┆ 20.5     ┆ 4      │
# │ 9997  ┆ 2024-03-31  ┆ 予          ┆ 2023-10-30 ┆ … ┆ 7000       ┆ 72.4       ┆ 20.5     ┆ 4      │
# │ 9997  ┆ 2025-03-31  ┆ 予          ┆ 2024-05-13 ┆ … ┆ 8000       ┆ 82.7       ┆ 29.0     ┆ 4      │
# └───────┴─────────────┴─────────────┴────────────┴───┴────────────┴────────────┴──────────┴────────┘
